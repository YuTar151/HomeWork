# %% [markdown]
# Створіть модель згорткової нейронної мережі із трьома шарами. Підключіть Tensorboard, та відобразіть в ньому зміну розподілу ваг моделі, обчислювальний граф моделі та зміну її метрик.

# %%
import numpy as np
import os
import datetime
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorboard import notebook

# %%
x = np.linspace(0, 10, 100)
y = 2*x + 1 + np.random.normal(scale=2, size=len(x))

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(32, activation='relu', input_dim=1),
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dense(1)
])

# компілювання моделі з функцією втрат MSE і оптимізатором Adam
model.compile(loss='mse', optimizer='adam')

# визначення callback для Tensorboard
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# навчання моделі на датасеті
model.fit(x, y, epochs=100, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 193ms/step - loss: 195.5149
# Epoch 2/100
# 4/4 [==============================] - 0s 46ms/step - loss: 186.7117
# Epoch 3/100
# 4/4 [==============================] - 0s 50ms/step - loss: 178.5289
# Epoch 4/100
# 4/4 [==============================] - 0s 50ms/step - loss: 170.2242
# Epoch 5/100
# 4/4 [==============================] - 0s 47ms/step - loss: 162.3911
# Epoch 6/100
# 4/4 [==============================] - 0s 46ms/step - loss: 155.1405
# Epoch 7/100
# 4/4 [==============================] - 0s 50ms/step - loss: 148.9781
# Epoch 8/100
# 4/4 [==============================] - 0s 51ms/step - loss: 142.6912
# Epoch 9/100
# 4/4 [==============================] - 0s 51ms/step - loss: 137.2901
# Epoch 10/100
# 4/4 [==============================] - 0s 47ms/step - loss: 132.5741
# Epoch 11/100
# 4/4 [==============================] - 0s 50ms/step - loss: 128.3726
# Epoch 12/100
# ...

# %%
y_pred = model.predict(x)

plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
notebook.start("--logdir " + os.path.abspath("logs/fit"))
# Out:
#       <iframe id="tensorboard-frame-d7b9adb8d3de9c9c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d7b9adb8d3de9c9c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "E:\ML_Projects\Study\venv\Scripts\tensorboard.exe\__main__.py", line 7, in <module>
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\main.py", line 46, in run_main
#     app.run(tensorboard.main, flags_parser=tensorboard.configure)
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\program.py", line 276, in main
#     return runner(self.flags) or 0
#            ^^^^^^^^^^^^^^^^^^
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\uploader\uploader_subcommand.py", line 691, in run
#     return _run(flags, self._experiment_url_callback)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\uploader\uploader_subcommand.py", line 124, in _run
#     intent.execute(server_info, channel)
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\uploader\uploader_subcommand.py", line 481, in execute
#     uploader.start_uploading()
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\uploader\uploader.py", line 213, in start_uploading
#     self._upload_once()
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\uploader\uploader.py", line 222, in _upload_once
#     self._logdir_loader.synchronize_runs()
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\uploader\logdir_loader.py", line 67, in synchronize_runs
#     for subdir in io_wrapper.GetLogdirSubdirectories(self._logdir):
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\backend\event_processing\io_wrapper.py", line 220, in <genexpr>
#     return (
#            ^
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorboard\backend\event_processing\io_wrapper.py", line 172, in ListRecursivelyViaWalking
#     for dir_path, _, filenames in tf.io.gfile.walk(top, topdown=True):
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 887, in walk_v2
#     for subitem in walk_v2(
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 887, in walk_v2
#     for subitem in walk_v2(
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 865, in walk_v2
#     listing = list_directory(top)
#               ^^^^^^^^^^^^^^^^^^^
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 748, in list_directory
#     return list_directory_v2(dirname)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\ML_Projects\Study\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 777, in list_directory_v2
#     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xce in position 93: invalid continuation byte
# (venv) PS E:\ML_Projects\Study>     'logs/fit'
